# %%
import pandas as pd
import pandas.io.data
import numpy as np
import datetime
from datetime import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10) 
# %matplotlib inline
seedval = 12345

# %%
np.random.seed(seedval)
a.plot()

# %%
total = a.cumsum()
pd.options.display.mpl_style = 'default'
total.plot()

# %%
b = pd.DataFrame(a)
b.plot()

# %%
#generate two column
np.random.seed(seedval)
df = pd.DataFrame(np.random.randn(10,3),index=a.index,columns=list('ABC'))
walkdf= df.cumsum()
walkdf.head()
# Out:
#                    A         B         C
# 2016-01-01 -0.204708  0.478943 -0.519439
# 2016-01-02 -0.760438  2.444724  0.873967
# 2016-01-03 -0.667530  2.726470  1.642990
# 2016-01-04  0.578905  3.733659  0.346769
# 2016-01-05  0.853896  3.962572  1.699685

# %%
walkdf.plot()

# %%
#stop at In 7
